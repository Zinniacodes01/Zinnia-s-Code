# %% [markdown]
# <a href="https://colab.research.google.com/github/Zinniacodes01/Zinnia-s-Code/blob/main/Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import accuracy_score as ac
from sklearn.metrics import confusion_matrix as cm
df=pd.read_csv('diabetes.csv')
x=df.drop('Outcome',axis=1)
y=df['Outcome']
trainx,testx,trainy,testy=tts(x,y,test_size=0.2)
model=LogisticRegression().fit(trainx,trainy)
y_predict=model.predict(testx)
print(round(ac(testy,y_predict),4)*100,'%')
print(cm(testy,y_predict))
# Out:
# 70.13000000000001 %
# [[81 16]
#  [30 27]]
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
df=pd.read_csv('Iris.csv')
x=df.drop('Species',axis=1)
df['Species']=df['Species'].map({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
y=df['Species']
trainx, testx, trainy, testy=tts(x,y,test_size=0.2)
model=LogisticRegression().fit(trainx,trainy)
y_predict=model.predict(testx)
print(ac(testy,y_predict)*100,'% accuracy')
print(cm(testy,y_predict))
# Out:
# 100.0 % accuracy
# [[12  0  0]
#  [ 0 10  0]
#  [ 0  0  8]]
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
